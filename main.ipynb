# %% [markdown]
# # Алгоритм приоритетного поиска с глобальными ограничениями для контроля генерации LLM
#
# модели и общие функции.

# %%
import pandas as pd, re
from sklearn.model_selection import train_test_split
from typing import List, Dict, Generator
import time, statistics, torch
from transformers import AutoTokenizer, AutoModelForCausalLM
import datasets
from profiling import time_avg, get_profile
import torch
import pandas as pd
from tqdm import tqdm
from profiling import time_avg, get_profile
import numpy as np

model_name = "Qwen/Qwen3-4B"
tok  = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True, padding_side='left')
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    torch_dtype=torch.bfloat16, 
    trust_remote_code=True,
    #memory_efficient_attention=True
).eval()

BATCH_SIZE = 8

def batches(tasks: pd.Series, prompts: List[Dict[str, str]], 
            user_message_template: str, batch_size: int = BATCH_SIZE) -> Generator[torch.tensor, None, None]:
    all_prompts = [prompts + [{"role": "user", "content": user_message_template.format(task) }] for task in tasks]

    chatml = [tok.apply_chat_template(prompt, tokenize=False, add_generation_prompt=True, 
                                       enable_thinking=False) for prompt in all_prompts]

    for i in range(0, len(chatml), batch_size):
        results = chatml[i:i+batch_size]
        enc = tok(results, return_tensors="pt", padding=True).to(model.device)
        yield enc, tasks.iloc[i:i+batch_size]
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# Создаем задачи для демонстрации

# %%
df = pd.read_csv("data/sudoku.csv")
train_sudoku, test_sudoku = train_test_split(df, test_size=10, random_state=42, shuffle=True)

sudoku_prompt = [
{
    "role": "system",
    "content": """
You are a Sudoku-solver.  Follow the rules exactly.

Input description:
    
- One string of 81 characters (row-major order).
- `0` = empty, your task to fill in them.
- `1-9` = fixed digits, you should not change them.
- Each 3x3 Block groups of neighbor rows and columns (nine digits) - is a **Block**
- To find the block for any position idx (0-80):

```
row    r = idx // 9         
column c = idx % 9   
block_row = r // 3   
block_col = c // 3
block_id  = block_row * 3 + block_col   
```

There is a mapping Input sequence (position shown in table cell) to Columns, Rows and Blocks:

      columns →
        0   1   2  │ 3   4   5  │ 6   7   8
      ┌────────────┼────────────┼────────────┐
rows 0│ 00  01  02 │ 03  04  05 │ 06  07  08 │
↓    1│ 09  10  11 │ 12  13  14 │ 15  16  17 │
     2│ 18  19  20 │ 21  22  23 │ 24  25  26 │
      ├────────────┼────────────┼────────────┤
     3│ 27  28  29 │ 30  31  32 │ 33  34  35 │
     4│ 36  37  38 │ 39  40  41 │ 42  43  44 │
     5│ 45  46  47 │ 48  49  50 │ 51  52  53 │
      ├────────────┼────────────┼────────────┤
     6│ 54  55  56 │ 57  58  59 │ 60  61  62 │
     7│ 63  64  65 │ 66  67  68 │ 69  70  71 │
     8│ 72  73  74 │ 75  76  77 │ 78  79  80 │
      └────────────┴────────────┴────────────┘


Rules to fill in 0-placeholders:

- **Each Row** must contain digits **1-9 exactly once**.  
- **Each Column** must contain digits **1-9 exactly once**.  
- **Each 3 x 3 Block** must contain digits **1-9 exactly once**.  
- **Fixed digits stay fixed** – every non-zero input digit must appear unchanged in the same position in your output.

Output format:

- Return **exactly one line of 81 digits**, no spaces or extra text.
- Order: row 1 (left→right) → row 2 → … → rdf = pd.DataFrame(datasets.load_dataset('allenai/common_gen', split='test'))

prompts = [
    tok.apply_chat_template(
        [{"role": "user",
          "content": f"write a sentence with the following words: [ {', '.join(c)} ]. Don't change words, tenses and include all words in the sentence."}],
        tokenize=False,
        add_generation_prompt=True,
        enable_thinking=False
    )
    for c in df["concepts"]
]ow 9 (the same as Input).
- Replace every `0` with the correct digit. 
- Keep all other digits unchanged!

Some examples:
""".strip()
  },

  {
    "role": "user",
    "content": "070000043040009610800634900094052000358460020000800530080070091902100005007040802"
  },
  {
    "role": "assistant",
    "content": "279518643543279618861634957694752318358461729712893534486927391932185465157346892"
  },

  {
    "role": "user",
    "content": "301086504046521070500000001400800002080347900009050038004090200008734090007208103"
  },
  {
    "role": "assistant",
    "content": "371986524846521379592473861463819752285347916719652438634195287128734695957268143"
  }
]
 
sdoku_batches = batches(test_sudoku['puzzle'], sudoku_prompt, "{}")

common_gen_df = pd.DataFrame(datasets.load_dataset('allenai/common_gen', split='validation'))
common_gen_batches = batches(common_gen_df['concepts'].map(lambda sl: ', '.join(sl)), [], 
                             "write a sentence with the following words: [ {} ]. Don't change words, tenses and include all words in the sentence.")

def is_include_all_words(str, concepts: list) -> bool:
    return all(word in str for word in concepts)

test_k_points = np.cumprod(np.arange(1, 6, 1))

# %% [markdown]
# ## Наш сэмплер

# %%
import random
import heapq

EOS_IDS = {
    tok.eos_token_id,
    tok.convert_tokens_to_ids("<|im_end|>"),
    tok.convert_tokens_to_ids("<|endoftext|>")
}

def tiny_noise(eps: float = 1e-7) -> float:
    """
    Возвращает случайное число в диапазоне (0, eps).
    По умолчанию eps = 1e-7, что на несколько порядков
    меньше типичных разниц -log P.
    """
    return random.random() * eps


def is_solution(ids: torch.Tensor) -> bool:
    return ids[-1].item() in EOS_IDS                

def canon_key(ids: torch.Tensor) -> int:              # анти-дубликатор
    return hash(tok.decode(ids, skip_special_tokens=False).strip())

def variants(
    prefix: torch.Tensor,
    batch_eval: int = 8,
    max_new: int = 200
):
    beam_width = batch_eval
    base_len   = prefix.size(0)

    frontier: list[tuple[int, float, torch.Tensor]] = [ (-base_len, 0.0, prefix.cpu()) ]
    visited = {canon_key(prefix.cpu())}

    while frontier:
        batch = [heapq.heappop(frontier) for _ in range(min(batch_eval, len(frontier)))]

        seqs_cpu, scores = [], []
        for neg_len, score, ids in batch:
            if is_solution(ids) or (ids.size(0) - base_len) >= max_new:
                yield ids, -score
            else:
                seqs_cpu.append(ids)
                scores.append(score)
        if not seqs_cpu:
            continue

        seqs_gpu = [s.to(model.device, non_blocking=True) for s in seqs_cpu]
        with torch.inference_mode():
            padded = torch.nn.utils.rnn.pad_sequence(
                seqs_gpu, batch_first=True, padding_value=tok.pad_token_id
            )
            last_logits = model(padded, use_cache=False).logits[
                torch.arange(len(seqs_gpu), device=padded.device),
                [len(s) - 1 for s in seqs_gpu]
            ]
        top_lp, top_tid = torch.topk(torch.log_softmax(last_logits, -1),
                                     beam_width, dim=-1)

        # ── 3. расширяем: greedy + альтернативы ──────────────────────────
        for ids_cpu, base_sc, lps, tids in zip(seqs_cpu, scores, top_lp, top_tid):
            for rank, (lp, tid) in enumerate(zip(lps, tids)):      # 0-й = greedy
                child_ids = torch.cat([ids_cpu, tid.view(1).cpu()])
                key       = canon_key(child_ids)
                if key in visited:
                    continue

                visited.add(key)
                child_score = base_sc - lp.item() + tiny_noise()

                # приоритет: сначала длина, потом лог-скор
                heapq.heappush(frontier, (-child_ids.size(0), child_score, child_ids))

# %% [markdown]
# ## Генерация нашим методом

# %%
def our_gen(k, common_gen_df):
    print('testing K=', k)
    data = list(batches(common_gen_df['concepts'].map(lambda sl: ', '.join(sl)), [], 
                                "write a sentence with the following words: [ {} ]. Don't change words, tenses and include all words in the sentence."))

    @time_avg
    def test_our_gen(data, steps=k):
        results = []
        for batch, concepts_batch in tqdm(data):
            for seq, concepts in zip(batch.input_ids, concepts_batch):
                for i, (res_tok, neg_logp) in enumerate(variants(seq, max_new=steps)):
                    text = tok.decode(res_tok, skip_special_tokens=True)
                    text = text.split('</think>')[1].strip()
                    if i > steps:
                        results.append("")
                        break
                    if is_include_all_words(text, concepts):
                        results.append(text)
                        break
        return results

    df_key_suffix = f'_our_gen_{k}'
    common_gen_df['result' + df_key_suffix] = test_our_gen(data)

    is_ok = []
    for _, row in common_gen_df.iterrows():
        concepts = row['concepts']
        is_ok.append(is_include_all_words(row['result' + df_key_suffix], concepts))

    common_gen_df['is_ok' + df_key_suffix] = is_ok

    print(f'Total time {k}:', get_profile())
    print(f'ACC ({k}):', common_gen_df['is_ok' + df_key_suffix].mean())

for k in test_k_points:
    our_gen(k, common_gen_df)
# Out:
# testing K= 1
# 100%|██████████| 503/503 [01:48<00:00,  4.63it/s]
# Total time 1: [('our_gen.<locals>.test_our_gen', 2, 109809.639001498)]
# ACC (1): 0.0
# testing K= 2
# 100%|██████████| 503/503 [06:46<00:00,  1.24it/s]
# Total time 2: [('our_gen.<locals>.test_our_gen', 1, 406763.78514198586)]
# ACC (2): 0.0
# testing K= 6
# 100%|██████████| 503/503 [27:53<00:00,  3.33s/it]
# Total time 6: [('our_gen.<locals>.test_our_gen', 1, 1673665.8450830146)]
# ACC (6): 0.004728720756595321
# testing K= 24
# 100%|██████████| 503/503 [1:43:19<00:00, 12.33s/it]
# Total time 24: [('our_gen.<locals>.test_our_gen', 1, 6199684.3787840335)]
# ACC (24): 0.5373320059731209
# testing K= 120
# 100%|██████████| 503/503 [2:03:25<00:00, 14.72s/it]
# Total time 120: [('our_gen.<locals>.test_our_gen', 1, 7405134.013422998)]
# ACC (120): 0.6070184171229467

# %% [markdown]
# ## Жадный алгоритм CommonGen

# %%
results = []
data = list(batches(common_gen_df['concepts'].map(lambda sl: ', '.join(sl)), [], 
                             "write a sentence with the following words: [ {} ]. Don't change words, tenses and include all words in the sentence."))

@time_avg
def test_free_gen(data):
    results = []
    is_oks = []
    for batch, concepts in tqdm(data):
        with torch.no_grad():
            gen = model.generate(batch.input_ids, attention_mask=batch.attention_mask, do_sample=False, top_p=None, top_k=None, temperature=None)
        texts = tok.batch_decode(gen, skip_special_tokens=True)
        texts = [text.split('</think>')[1].strip() for text in texts]
        results.extend(texts)
        is_oks.append([is_include_all_words(text, concept) for text, concept in zip(texts, concepts)])
    return results, is_oks

results, is_oks = test_free_gen(data)

common_gen_df['free_gen_result'] = results
common_gen_df['is_ok_free_gen'] = [x for xs in is_oks for x in xs]

print(f'Total time: {get_profile()}')
print('ACC:', common_gen_df['is_ok_free_gen'].mean())
# Out:
# 100%|██████████| 503/503 [04:33<00:00,  1.84it/s]
# Total time: [('test_free_gen', 1, 273475.7408319856)]
# ACC: 0.35739173718267797

# %% [markdown]
# ## Nuclius sampling + проверка

# %%
results = []
data = list(batches(common_gen_df['concepts'].map(lambda sl: ', '.join(sl)), [], 
                             "write a sentence with the following words: [ {} ]. Don't change words, tenses and include all words in the sentence."))

@time_avg
@torch.inference_mode()
def test_free_gen_nucleus(
    data_loader,
    max_tries: int = 40,
    top_p: float = 0.95,
    temperature: float = 0.5,
    max_new_tokens: int | None = None,
):
    all_results = []

    for batch, concepts in tqdm(data_loader):
        # 👉 превратим Series в список с 0-based позициями
        concepts = list(concepts)               # или concepts.reset_index(drop=True)

        batch_size     = batch.input_ids.size(0)
        unfinished     = torch.ones(batch_size, dtype=torch.bool, device=batch.input_ids.device)
        batch_results  = [None] * batch_size

        for _ in range(max_tries):
            if not unfinished.any():
                break

            idx = unfinished.nonzero(as_tuple=False).flatten()

            gen = model.generate(
                batch.input_ids[idx],
                attention_mask=batch.attention_mask[idx],
                do_sample=True,
                top_p=top_p,
                temperature=temperature,
                max_new_tokens=max_new_tokens,
                pad_token_id=tok.pad_token_id,
            )

            decoded = tok.batch_decode(gen, skip_special_tokens=True)

            for i, text in zip(idx.tolist(), decoded):
                text = text.split('</think>')[1].strip() if '</think>' in text else text
                if is_include_all_words(text, concepts[i]):
                    batch_results[i] = text
                    unfinished[i]   = False

        # те, что не прошли 40 попыток
        batch_results = [s or "" for s in batch_results]
        all_results.extend(batch_results)

    return all_results


common_gen_df['nuc_gen_result'] = test_free_gen_nucleus(data)

is_ok = []
for _, row in common_gen_df.iterrows():
    concepts = row['concepts']
    is_ok.append(is_include_all_words(row['nuc_gen_result'], concepts))

common_gen_df['is_ok_nuc_gen'] = is_ok

print(f'Total time (nucleus): {get_profile()}')
print('ACC (nucles):', common_gen_df['is_ok_nuc_gen'].mean())
# Out:
# 100%|██████████| 503/503 [2:02:36<00:00, 14.62s/it]
# Total time (nucleus): [('test_free_gen_nucleus', 1, 7356091.35289496)]
# ACC (nucles): 0.226231956197113

# %% [markdown]
# K==100, p=0

# %%
results = []
data = list(batches(common_gen_df['concepts'].map(lambda sl: ', '.join(sl)), [], 
                             "write a sentence with the following words: [ {} ]. Don't change words, tenses and include all words in the sentence."))

@time_avg
@torch.inference_mode()
def test_free_gen_nucleus(
    data_loader,
    max_tries: int = 100,
    top_p: float = 1.0,
    temperature: float = None,
    max_new_tokens: int | None = None,
):
    all_results = []

    for batch, concepts in tqdm(data_loader):
        # 👉 превратим Series в список с 0-based позициями
        concepts = list(concepts)               # или concepts.reset_index(drop=True)

        batch_size     = batch.input_ids.size(0)
        unfinished     = torch.ones(batch_size, dtype=torch.bool, device=batch.input_ids.device)
        batch_results  = [None] * batch_size

        for _ in range(max_tries):
            if not unfinished.any():
                break

            idx = unfinished.nonzero(as_tuple=False).flatten()

            gen = model.generate(
                batch.input_ids[idx],
                attention_mask=batch.attention_mask[idx],
                do_sample=True,
                top_p=top_p,
                temperature=temperature,
                max_new_tokens=max_new_tokens,
                pad_token_id=tok.pad_token_id,
            )

            decoded = tok.batch_decode(gen, skip_special_tokens=True)

            for i, text in zip(idx.tolist(), decoded):
                text = text.split('</think>')[1].strip() if '</think>' in text else text
                if is_include_all_words(text, concepts[i]):
                    batch_results[i] = text
                    unfinished[i]   = False

        # те, что не прошли 40 попыток
        batch_results = [s or "" for s in batch_results]
        all_results.extend(batch_results)

    return all_results


common_gen_df['nuc_gen_result'] = test_free_gen_nucleus(data)

is_ok = []
for _, row in common_gen_df.iterrows():
    concepts = row['concepts']
    is_ok.append(is_include_all_words(row['nuc_gen_result'], concepts))

common_gen_df['is_ok_nuc_gen'] = is_ok

print(f'Total time (nucleus): {get_profile()}')
print('ACC (nucles):', common_gen_df['is_ok_nuc_gen'].mean())
# Out:
# 100%|██████████| 503/503 [4:00:44<00:00, 28.72s/it]
# Total time (nucleus): [('test_free_gen_nucleus', 1, 14444126.722427027)]
# ACC (nucles): 0.35714285714285715

# %% [markdown]
# K=1000

# %%
results = []
data = list(batches(common_gen_df['concepts'].map(lambda sl: ', '.join(sl)), [], 
                             "write a sentence with the following words: [ {} ]. Don't change words, tenses and include all words in the sentence."))

@time_avg
@torch.inference_mode()
def test_free_gen_nucleus(
    data_loader,
    max_tries: int = 1000,
    top_p: float = 1.0,
    temperature: float = None,
    max_new_tokens: int | None = None,
):
    all_results = []

    for batch, concepts in tqdm(data_loader):
        # 👉 превратим Series в список с 0-based позициями
        concepts = list(concepts)               # или concepts.reset_index(drop=True)

        batch_size     = batch.input_ids.size(0)
        unfinished     = torch.ones(batch_size, dtype=torch.bool, device=batch.input_ids.device)
        batch_results  = [None] * batch_size

        for _ in range(max_tries):
            if not unfinished.any():
                break

            idx = unfinished.nonzero(as_tuple=False).flatten()

            gen = model.generate(
                batch.input_ids[idx],
                attention_mask=batch.attention_mask[idx],
                do_sample=True,
                top_p=top_p,
                temperature=temperature,
                max_new_tokens=max_new_tokens,
                pad_token_id=tok.pad_token_id,
            )

            decoded = tok.batch_decode(gen, skip_special_tokens=True)

            for i, text in zip(idx.tolist(), decoded):
                text = text.split('</think>')[1].strip() if '</think>' in text else text
                if is_include_all_words(text, concepts[i]):
                    batch_results[i] = text
                    unfinished[i]   = False

        # те, что не прошли 40 попыток
        batch_results = [s or "" for s in batch_results]
        all_results.extend(batch_results)

    return all_results


common_gen_df['nuc_gen_result'] = test_free_gen_nucleus(data)

is_ok = []
for _, row in common_gen_df.iterrows():
    concepts = row['concepts']
    is_ok.append(is_include_all_words(row['nuc_gen_result'], concepts))

common_gen_df['is_ok_nuc_gen'] = is_ok

print(f'Total time (nucleus): {get_profile()}')
print('ACC (nucles):', common_gen_df['is_ok_nuc_gen'].mean())
# Out:
#  15%|█▌        | 77/503 [5:17:56<16:53:53, 142.80s/it]

# %% [markdown]
# # Анасамбль слабых правил
#
# ## Голосование простым большинством

# %% [markdown]
# Правила

# %%
import random
from enum import Enum, auto


class Verdicts(Enum):
    ACCEPT = auto()
    REJECT = auto()
    ABSTAIN = auto()


def is_ok(text: str, word1: str, word2: str, word3: str, banned_word: str) -> bool:
    # Правила 1–3: проверка наличия обязательных слов
    def check_word(word: str, text: str) -> Verdicts:
        """Возвращает вердикт для правила, проверяющего наличие слова в тексте."""
        if word == "" or word is None or not (word in text):
            return Verdicts.ABSTAIN      # Слово не задано
        return Verdicts.ACCEPT
    
    verdicts = []
    # Проверяем первые три слова по правилам 1-3
    verdicts.append(check_word(word1, text))
    verdicts.append(check_word(word2, text))
    verdicts.append(check_word(word3, text))
    
    def random_verdict(_: str, text: str) -> Verdicts:
        rand_value = random.random()  # получаем число [0.0, 1.0)
        if rand_value < 0.3:
            return Verdicts.ACCEPT
        elif rand_value < 0.7:
            return Verdicts.REJECT
        else:
            return Verdicts.ABSTAIN
    
    verdicts.append(random_verdict("", text))
    
    def is_banned(banned_word: str, text: str) -> Verdicts:
        if banned_word is not None and banned_word != "" and banned_word in text:
            return Verdicts.REJECT
        else:
            return Verdicts.ABSTAIN
    

    verdicts.append(is_banned(banned_word, text))
    
    # Подсчёт голосов "принять" и "отказать"
    accept_count = verdicts.count(Verdicts.ACCEPT)
    reject_count = verdicts.count(Verdicts.REJECT)
 
    if reject_count > accept_count:
        return False
    return True

# %%
from typing import List


@time_avg
def gen_batch(model_generate, puzzles: List[str]) -> List[str]:
    """
    puzzles : список строк-судоку
    model_generate : функция-обёртка вокруг model.generate (т.к. вы
                     передаёте lambda input: model.generate(...))
    ↩︎  список строк-ответов (только генерация)
    """
    # 1) строим список промптов (один на каждый пазл)
    prompt_texts = [
        tok.apply_chat_template(
            prompt + [{"role": "user", "content": p}],
            tokenize=False,
            add_generation_prompt=True,
            enable_thinking=False
        )
        for p in puzzles
    ]

    # 2) токенизируем как настоящий batch
    enc = tok(prompt_texts, return_tensors="pt", padding=True).to(model.device)

    # 3) вызываем генератор (он уже внутри lambda)
    with torch.no_grad():
        out_ids = model_generate(enc)          # shape: [B, L_gen]

    out_ids = out_ids.cpu()
    answers = []
    for i, prompt_len in enumerate((enc.input_ids != tok.pad_token_id).sum(1)):
        gen_part = out_ids[i, prompt_len:]     # обрезаем префикс-промпт
        answers.append(tok.decode(gen_part, skip_special_tokens=True).strip())
    return answers


# ── обёртка для удобного вызова в pandas-цикле  ─────────────────────
def calc_all(df, model):
    BATCH = 2
    results = []
    reset_profile()

    generator = lambda enc: model.generate(
        enc.input_ids,
        attention_mask=enc.attention_mask,
        top_p=0.9,
        temperature=0.8,
        max_new_tokens=300
    )

    for i in tqdm(range(0, len(df), BATCH)):
        puzzles = df["puzzle"].iloc[i:i+BATCH].tolist()
        results.extend(gen_batch(generator, puzzles))

    return results


# ── запуск  ─────────────────────────────────────────────────────────
test["free_gen_solution"] = calc_all(test, model)
print_profile()
test[test["solution"] == test["free_gen_solution"]]
# Out:
# 100%|██████████| 5/5 [05:40<00:00, 68.06s/it]
# function                                             calls     avg ms
# gen_batch                                                5  68057.332
# Empty DataFrame
# Columns: [puzzle, solution, cls_gen_solution, free_gen_solution]
# Index: []

# %%
import re, torch, torch.nn.functional as F
from enum   import Enum, auto
from typing import List, Dict, Tuple, Callable

# ---- Verdict enum -------------------------------------------------
class Verdict(Enum):
    REJECT   = auto()
    CONTINUE = auto()
    ACCEPT   = auto()

_puzzle_re = re.compile(r"[0-9]{81}")   # ищем строку-пазл
_digit_re  = re.compile(r"[0-9]")       # одиночные цифры

def sudoku_rule(text: str, history: List[Dict[str, str]]) -> Verdict:
    """
    • text    – текущий вывод LLM (префикс).
    • history – диалог; в последнем user-сообщении ищем 81-символьный пазл.

    Правило:
    1. В text (после strip()) должны быть **только цифры 0-9**.  
       Любой другой символ – сразу REJECT.
    2. Кол-во цифр ≤ 81.  >81 → REJECT.
    3. Заданные цифры из puzzle неизменны.
    4. Нет дубликатов в строках, столбцах, блоках.
    5. Если все 81 ячейка заполнена и п. 4 выполнен → ACCEPT,
       иначе (цифр <81) → CONTINUE.
    """
    puzzle = None
    for msg in reversed(history):
        if msg["role"] == "user":
            hit = _puzzle_re.findall(msg.get("content", ""))
            if hit:
                puzzle = hit[-1]
                break
    if puzzle is None:
        return Verdict.REJECT

    stripped = text.strip()
    if not stripped.isdigit():          # любой не-digit → reject
        return Verdict.REJECT

    digits = list(stripped)
    if len(digits) > 81:                # длиннее сетки
        return Verdict.REJECT

    for p, d in zip(puzzle, digits):
        if p != "0" and p != d:
            return Verdict.REJECT

    digits += ["0"] * (81 - len(digits))
    rows = [digits[i*9:(i+1)*9] for i in range(9)]
    cols = list(zip(*rows))
    blks = [digits[r*27+c*3:r*27+c*3+27:9] +
            digits[r*27+c*3+1:r*27+c*3+28:9] +
            digits[r*27+c*3+2:r*27+c*3+29:9]
            for r in range(3) for c in range(3)]

    for unit in rows + [list(c) for c in cols] + blks:
        nums = [x for x in unit if x != "0"]
        if len(nums) != len(set(nums)):
            return Verdict.REJECT

    return Verdict.ACCEPT if "0" not in digits else Verdict.CONTINUE


# ---- helpers ------------------------------------------------------
def _pad(batch: List[List[int]], pad_id, device):
    L = max(map(len, batch))
    t = torch.full((len(batch), L), pad_id, dtype=torch.long, device=device)
    for i, seq in enumerate(batch):
        t[i, :len(seq)] = torch.tensor(seq, device=device)
    return t

def in_think(txt: str) -> bool:
    o = txt.rfind("<think>"); c = txt.rfind("</think>")
    return o != -1 and (c == -1 or c < o)

# ---- beam-search --------------------------------------------------
def beam_generate(
    model,
    tok,
    prompts: List[str],
    *,
    beam_size: int = 16,
    max_new_tokens: int = 120,
    sub_bs: int = 2,
    rule: Callable[[str, List[Dict[str,str]]], Verdict] = sudoku_rule,
) -> List[str]:

    dev   = next(model.parameters()).device
    eos   = tok.eos_token_id
    pad   = tok.pad_token_id
    vocab = model.config.vocab_size             # ← фикс

    p_ids = [tok.encode(p, add_special_tokens=False) for p in prompts]
    batch = len(prompts)

    # histories per prompt
    histories = [[{"role":"user","content":_puzzle_re.findall(p)[-1]}]
                 for p in prompts]

    # digit mask on GPU
    mask = torch.full((vocab,), -1e9, device=dev)
    for d in "123456789":
        mask[tok.convert_tokens_to_ids(d)] = 0.0
    mask[eos] = 0.0

    def score(ids_lists: List[List[int]]) -> torch.Tensor:
        outs = []
        for i in range(0, len(ids_lists), sub_bs):
            ids = _pad(ids_lists[i:i+sub_bs], pad, dev)
            att = (ids != pad).long()
            with torch.no_grad():
                logits = model(ids, attention_mask=att,
                               logits_to_keep=1, use_cache=False).logits[:, -1]
            outs.append(torch.log_softmax(logits + mask, -1))
        return torch.cat(outs, 0)

    first_lp = score(p_ids)
    beams  = [[] for _ in range(batch)]   # (ids, txt, score)
    closed = [[] for _ in range(batch)]

    for qi, lp_row in enumerate(first_lp):
        lp, idx = torch.topk(lp_row, beam_size)
        for sc, tid in zip(lp.tolist(), idx.tolist()):
            s = tok.convert_ids_to_tokens([tid])[0]
            if tid == eos:
                if rule("", histories[qi]) is Verdict.ACCEPT:
                    closed[qi].append(([], "", sc))
            else:
                v = Verdict.CONTINUE if in_think(s) else rule(s, histories[qi])
                if v is not Verdict.REJECT:
                    beams[qi].append(([tid], s, sc))

    for _ in range(max_new_tokens - 1):
        active, back = [], []
        for qi, bl in enumerate(beams):
            for bi, (ids, txt, sc) in enumerate(bl):
                active.append(p_ids[qi] + ids)
                back.append((qi, bi))
        if not active: break

        lp_all = score(active)
        new_pool = [[] for _ in range(batch)]

        for row, (qi, bi) in enumerate(back):
            base_ids, base_txt, base_sc = beams[qi][bi]
            lp, idx = torch.topk(lp_all[row], beam_size)

            for add, tid in zip(lp.tolist(), idx.tolist()):
                s     = tok.convert_ids_to_tokens([tid])[0]
                ids2  = base_ids + [tid]
                txt2  = base_txt + s
                sc2   = base_sc + add

                if tid == eos:
                    if in_think(base_txt) or \
                       rule(base_txt, histories[qi]) is Verdict.ACCEPT:
                        closed[qi].append((base_ids, base_txt, sc2))
                    continue

                v = Verdict.CONTINUE if in_think(txt2) else rule(txt2, histories[qi])
                if v is Verdict.REJECT:
                    continue
                new_pool[qi].append((ids2, txt2, sc2))

        beams = []
        for pool in new_pool:
            pool.sort(key=lambda x: x[2], reverse=True)
            beams.append(pool[:beam_size])
        if all(not bl for bl in beams): break

    outs = []
    for qi in range(batch):
        cand = closed[qi] if closed[qi] else beams[qi]
        best_txt = max(cand, key=lambda x: x[2])[1] if cand else ""
        outs.append(best_txt)
    return outs

def calc_all(df):
    BATCH = 2
    res = []
    for i in tqdm(range(0, len(df), BATCH)):
        puzzles = df["puzzle"].iloc[i:i+BATCH].tolist()
        prompts = tok.apply_chat_template(
            [prompt + [{"role":"user","content":p}] for p in puzzles],
            tokenize=False, add_generation_prompt=True, enable_thinking=False
        )
        res.extend(beam_generate(model, tok, prompts))
    return res
    
prompt_texts = [
        tok.apply_chat_template(
            prompt + [{"role": "user", "content": p}],
            tokenize=False,
        )
        for p in puzzles
    ]

    # 2) токенизируем как настоящий batch
    enc = tok(prompt_texts, return_tensors="pt", padding=True).to(model.device)_gen_solution"] = calc_all(test)
# Out:
# 100%|██████████| 5/5 [1:06:41<00:00, 800.29s/it]

# %%
EOS_IDS   = {tok.eos_token_id, tok.convert_tokens_to_ids("<|im_end|>"),tok.convert_tokens_to_ids("<|endoftext|>") } 

import heapq, itertools, torch
from typing import Generator, List, Tuple, Callable
from enum import Enum, auto

def tiny_noise(ids: torch.Tensor, eps: float = 1e-7) -> float:
    h = hash(ids.numpy().tobytes()) & 0xFFFF    # 16 бит
    return eps * h / 65535.0

# ──  условие «решение» (по умолчанию: любой EOS)  ────────────────────────
def is_solution(ids: torch.Tensor) -> bool:
    return ids[-1].item() in EOS_IDS

# ──  глубина-сначала + best-first  ───────────────────────────────────────
def variants(
    prefix: torch.Tensor,
    beam_width: int = 8,
    batch_eval: int = 4,
    max_new:   int = 128,
) -> Generator[Tuple[torch.Tensor, float], None, None]:
    """
    Генератор (ids, log_prob):
      • приоритет (-len, score)  →  всегда раскрываем самую длинную ветку;
      • visited-set предотвращает дубли;
      • поиск полон, пока max_new конечен.
    """
    base_len = prefix.size(0)                   # длина исходного префикса
    visited = {hash(prefix.cpu().numpy().tobytes())}

    # frontier на CPU: (-len, score+noise, ids_CPU)
    frontier: List[Tuple[int, float, torch.Tensor]] = [
        (-base_len, 0.0, prefix.cpu())
    ]
    heapq.heapify(frontier)

    while frontier:
        # ── 1. формируем батч самых длинных гипотез ──
        batch = [heapq.heappop(frontier)
                 for _ in range(min(batch_eval, len(frontier)))]

        # распаковываем
        seqs_cpu, scores = [], []
        for neg_len, score, ids in batch:
            if is_solution(ids) or (ids.size(0) - base_len) >= max_new:
                yield ids, -score
            else:
                seqs_cpu.append(ids)
                scores.append(score)

        if not seqs_cpu:         # весь батч уже дал решения
            continue

        # ── 2. один forward на GPU  ─────────────────────────────
        seqs_gpu = [s.to(model.device, non_blocking=True) for s in seqs_cpu]
        with torch.inference_mode():
            padded = torch.nn.utils.rnn.pad_sequence(
                seqs_gpu, batch_first=True, padding_value=tok.pad_token_id
            )
            logits = model(padded, use_cache=False).logits
            last = logits[
                torch.arange(len(seqs_gpu), device=logits.device),
                [len(s) - 1 for s in seqs_gpu]
            ]
        logp    = torch.log_softmax(last, -1)
        top_lp, top_tid = torch.topk(logp, beam_width, dim=-1)

        # ── 3. расширяем: greedy + альтернативы ─────────────────
        for ids_cpu, base_score, best_lp, best_tid, alt_lps, alt_tids in zip(
                seqs_cpu, scores,
                top_lp[:, 0], top_tid[:, 0],
                top_lp[:, 1:], top_tid[:, 1:]):

            # (а) альтернативы
            for lp, tid in zip(alt_lps, alt_tids):
                child = torch.cat([ids_cpu, tid.view(1).cpu()])
                key = canon_key(child)
                if key not in visited:
                    visited.add(key)
                    child_score = base_score - lp.item() + tiny_noise(child)
                    heapq.heappush(frontier,
                                   (-child.size(0), child_score, child))

            # (б) greedy-первый (рассматривается раньше из-за DFS)
            best = torch.cat([ids_cpu, best_tid.view(1).cpu()])
            key = hash(best.numpy().tobytes())
            if key not in visited:
                visited.add(key)
                best_score = base_score - best_lp.item() + tiny_noise(best)
                heapq.heappush(frontier, (-best.size(0), best_score, best))



class Verdict(Enum):
    REJECT   = auto()
    CONTINUE = auto()
    ACCEPT   = auto()

_puzzle_re = re.compile(r"[0-9]{81}")   # ищем строку-пазл
_digit_re  = re.compile(r"[0-9]")       # одиночные цифры

def sudoku_rule(text: str) -> Verdict:
    stripped = text.strip()
    if not stripped.isdigit():          # любой не-digit → reject
        return Verdict.REJECT

    digits = list(stripped)
    if len(digits) > 81:                # длиннее сетки
        return Verdict.REJECT

    digits += ["0"] * (81 - len(digits))
    rows = [digits[i*9:(i+1)*9] for i in range(9)]
    cols = list(zip(*rows))
    blks = [digits[r*27+c*3:r*27+c*3+27:9] +
            digits[r*27+c*3+1:r*27+c*3+28:9] +
            digits[r*27+c*3+2:r*27+c*3+29:9]
            for r in range(3) for c in range(3)]

    for unit in rows + [list(c) for c in cols] + blks:
        nums = [x for x in unit if x != "0"]
        if len(nums) != len(set(nums)):
            return Verdict.REJECT

    return Verdict.ACCEPT if "0" not in digits else Verdict.CONTINUE



enc = tok([tok.apply_chat_template(
            prompt + [{"role": "user", "content": p}],
            tokenize=False,
            add_generation_prompt=True,
            enable_thinking=False
        ) for p in test['puzzle'].tolist()], return_tensors="pt", padding=True).to(model.device).input_ids

res = []
for pr, p, sol in zip(enc, test['puzzle'].tolist(), test['solution'].tolist()): 
    print('Puzzle', p)
    print('Soolution', sol)
    for seq, neg_logp in variants(pr):
        text = tok.decode(seq, skip_special_tokens=True)#.split('</think>')[1].strip()
        if '</think>' in text:
            text = text.split('</think>')[1].strip()
        else:
            print('not finished thoths', text)
            print()
        if sudoku_rule(text) == Verdict.ACCEPT:
            res.append(text)
            print("\tAccepted solution:", text)
            break
        else:
            print('\tRejected solution:', text)
# Out:
# Puzzle 910700000065800000078004695020401007081000209006000400003670908000108030040509176
# Soolution 914756823265893714378214695529481367481367259736925481153672948697148532842539176
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864365814297783269514249317685817645329634928751591476238428531976176893452
# 	Rejected solution: 912753864365814297783269514249317685817645329654928731136879452528431976971586342
# 	Rejected solution: 912753864365814297783269514249317685817645329654928731136879452528431976971586243
# 	Rejected solution: 9127538648653241973789156242346875197514693826931724581825967344762389155498132676
# 	Rejected solution: 9127538643658142977832695142493176858176453296349287515914762384285319761768934523
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864365814297783269514249317685817645329634928751591476238428531976176893452
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# ...
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# 	Rejected solution: 912753864865324197378915624234687519751469382693172458182596734476238915549813267
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 143
#     141 print('Puzzle', p)
#     142 print('Soolution', sol)
# --> 143 for seq, neg_logp in variants(pr):
#     144     text = tok.decode(seq, skip_special_tokens=True)#.split('</think>')[1].strip()
#     145     if '</think>' in text:
#
# Cell In[6], line 59, in variants(prefix, beam_width, batch_eval, max_new, is_solution)
#      57 # ── 2. один forward на GPU  ─────────────────────────────
#      58 seqs_gpu = [s.to(model.device, non_blocking=True) for s in seqs_cpu]
# ---> 59 with torch.inference_mode():
#      60     padded = torch.nn.utils.rnn.pad_sequence(
#      61         seqs_gpu, batch_first=True, padding_value=tok.pad_token_id
#      62     )
#      63     logits = model(padded, use_cache=False).logits
#
# File /storage/work/misis_materials/article/experiments/.venv/lib/python3.12/site-packages/torch/autograd/grad_mode.py:273, in inference_mode.__exit__(self, exc_type, exc_value, traceback)
#     270     self._inference_mode_context = torch._C._InferenceMode(self.mode)
#     271     self._inference_mode_context.__enter__()
# --> 273 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     274     self._inference_mode_context.__exit__(exc_type, exc_value, traceback)
#     276 def clone(self) -> "inference_mode":
#
# KeyboardInterrupt:

# %%
test['solution'].iloc[0]
# Out:
# '914756823265893714378214695529481367481367259736925481153672948697148532842539176'

# %%
import datasets
import torch


df = pd.DataFrame(datasets.load_dataset('allenai/common_gen', split='test'))

prompts = [
    tok.apply_chat_template(
        [{"role": "user",
          "content": f"write a sentence with the following words: [ {', '.join(c)} ]. Don't change words, tenses and include all words in the sentence."}],
        tokenize=False,
        add_generation_prompt=True,
        enable_thinking=False
    )
    for c in df["concepts"]
]

batch_size = 32          # подбери под свою видеокарту (8-32 обычно ок)
results = []

for start in tqdm(range(0, len(prompts), batch_size)):
    batch_prompts = prompts[start : start + batch_size]

    enc = tok(
        batch_prompts,
        padding=True,
        return_tensors="pt"
    ).to(model.device)                            # токены на GPU

    with torch.no_grad():                   # экономим память, убираем градиенты
        gen = model.generate(
            input_ids=enc.input_ids,
            attention_mask=enc.attention_mask,
            top_p=0.9,
            temperature=0.8,
            max_new_tokens=300
        )

    results.extend(tok.batch_decode(gen, skip_special_tokens=True))

    # подчистить, чтобы освободить VRAM
    del enc, gen
    torch.cuda.empty_cache()

for s in [s.split('</think>')[1] for s in results]:
    print(s)
# Out:
# 100%|██████████| 47/47 [01:17<00:00,  1.66s/it]
# The team practiced a new drill on the field.
#
#
# The player took a shot at the goal.
#
#
# I threw the frisbee to my dog, and he caught it right away.
#
#
# She sat at the front of the table to eat the food.
#
#
# She sat at the front of the stage, holding a guitar and pointing toward the microphone.
#
#
# I used a metal tool to cut the piece of metal.
#
#
# The dog walked on the sidewalk with a leash.
#
#
# She stepped onto the stage, ready to perform her carefully rehearsed routine, the music filling the air with energy and rhythm.
#
#
# I will use the machine to sew and demonstrate how to operate it.
#
#
# I used the stove to cook food in the pan.
#
#
# The player wore the jersey on the field.
#
#
# The door was open, but the refrigerator was closed.
#
#
# I push the lawn mower to mow the grass on the lawn.
#
#
# He held the marshmallow over the fire, carefully roasting it until it was golden and sticky, then carefully stuck it on a skewer to finish cooking.
#
#
# The couple sat at the table for dinner.
#
#
# She put on her lipstick and began to talk about her favorite song, smiling as she leaned in to kiss the lip of her friend.
#
#
# I was driving down the road when I saw a car floating on the water.
#
#
# The background was decorated with a tree and soft music playing softly.
#
#
# I want to eat a donut, but I need to hang the string on the door first.
#
#
# She took a trail through the wood on her bike for a ride.
#
#
# She rode the boat across the water, stepping off the board as it reached the shore.
#
#
# I sat on the chair and ate the food.
#
#
# The dancers performed a captivating dance routine to the upbeat music, with the front row audience cheering enthusiastically.
#
#
# The team worked hard to improve their game, aiming for a higher score and a crucial goal to secure the win.
#
#
# The player stood on the field, ready to practice, and tried to hit the ball.
#
#
# I used a knife to cut the watermelon in the kitchen.
#
#
# The white of the egg was separate from the yolk, and the bottle held the remaining contents.
#
#
# The athlete practiced throwing the javelin on the track and also worked on improving his running speed.
#
#
# She walked down the street while talking on her cellphone.
#
#
# The lights danced to the beat of the music, creating a flash of color that illuminated the room.
#
#
# The guitarist carefully moved their hand along the neck of the guitar.
#
#
# The dog chased the ball across the grass.
#
#
# I walked along the beach, enjoying the soft sand and my dog.
#
#
# She jumped over the pole and landed safely on the mat after a quick run.
#
#
# The boat was caught in the net and drifted slowly through the water.
#
#
# She rode her bike along the sidewalk, carefully avoiding the wheel of the car in front of her.
#
#
# I used the sewing machine to sew a beautiful piece of fabric together.
#
#
# I pushed the mower across the grass to cut the lawn.
#
#
# I will put an ornament on the tree to decorate it for the holiday.
#
#
# I turned the knob to open the door.
#
#
# She wore a beautiful dress and stood on the sidewalk, smiling at the sunset.
#
#
# The dog ran around the area, jumping over the fence.
#
#
# I poured a drink from the bottle into the glass.
#
#
# After finishing his shower, he stood in the bathtub, ready to shave his leg.
#
#
# She threw the object with a spin, covering a great distance.
#
#
# I will take a picture from the front stand.
#
#
# She sat quietly, her finger tapping the table as she smiled softly, then snapped her fingers in delight.
#
#
# The team will compete in the game on the field.
#
#
# She wore a shirt and rode a scooter, enjoying the ride while wearing the shirt.
#
#
# The dog ran under the tree as snow fell gently from the sky.
#
#
# I jumped on the trampoline and threw the ball high into the air.
#
#
# She performed a graceful juggle under the soft background music, with a ball in hand.
#
#
# She read the newspaper while sipping her coffee and enjoying her drink.
#
#
# She clapped her hand to the rhythm of the song, singeing her fingers from the hot air.
#
#
# I will use the mop to clean the floor.
#
#
# She stood at the front of the room to give a presentation.
#
#
# I used the hand to wash my hands in the sink with soap.
#
#
# She tied a rope around the tree to help her walk up the cliff.
#
#
# I added the ingredient to the pan and started to fry it.
#
#
# I took my dog for a walk along the street at night.
#
#
# The crowd gathered around the music and began to dance, watching the lively performance with excitement.
#
#
# He carefully cut the piece of meat with a sharp knife.
#
#
# She sailed across the water on her surfboard, riding the waves with excitement.
#
#
# The dancer moved gracefully on the stage, with the music and background lighting creating a mesmerizing performance.
#
#
# I applied cream to my face before shaving.
#
#
# She lay on the table, receiving a relaxing massage that she gave to her friend.
#
#
# I held my hand out as I walked through the water.
#
#
# I wore a coat as I walked along the sidewalk.
#
#
# She decided to dig a hole in the ground to plant a new tree.
#
#
# The ski lift climbed up the hill, where the snow covered the forest floor.
#
#
# She sat at the table with a light candle in front of her.
#
#
# I flipped the pancake in the fry pan until it was golden and crispy.
#
#
# The band will perform on the field during the march.
#
#
# The cat used the clip to hold the nail in place.
#
#
# The dog performed a trick with the frisbee.
#
#
# I will demonstrate how to knit using a yarn and a needle.
#
#
# He went to the gym to press the weight on the bench.
#
#
# I sat on the beach, holding a small alligator in my mouth.
#
#
# I used a piece of wood to cut the paper.
#
#
# She poured the ingredient into the bowl and began to mix it thoroughly.
#
#
# The worker wore a vest to work.
#
#
# The band took the stage and performed for a large crowd.
#
#
# The worker sat down to eat lunch.
#
#
# She sat on the chair, but she fell off and landed on the floor.
#
#
# She lay on the bed, reading a book.
#
#
# She sat on the bed and carefully comb her hair.
#
#
# She drew a piece of paper with a marker.
#
#
# The cowboy rode his horse, lassoed a cow, and enjoyed the ride through the open plains.
#
#
# She used a spray can to paint a vibrant design on the wall.
#
#
# The catcher caught the ball and threw it to first base.
#
#
# She decided to walk down the street while wearing a fresh shirt.
#
#
# Sander walked through the house and looked down at the sand on the floor.
#
#
# The boy tried to tug the toy from the dog during the war.
#
#
# After finishing his chores, he left the rake in the pile and jumped over the fence.
#
#
# I blew a bubble, and when it popped, it left a small mark on my face.
#
#
# She motorized her scooter and enjoyed a smooth ride along the busy street.
#
#
# She lay on the bed, giggling as her friend tickled her and made her laugh.
#
#
# He looked at the cigarette and decided to continue smoking.
#
#
# The swimmer competed in the race at the pool.
#
#
# The surfer stood on the ocean, ready to catch the wave on his surfboard.
#
#
# She looked at the face of the person holding the plate of food and decided to eat.
#
#
# The player dribbled the ball across the court.
#
#
# The stylist used iron to straighten the client's hair, demonstrating the effectiveness of the tool.
#
#
# The ball rolled down the alley and hit the fence.
#
#
# I looked in the mirror, brushed my teeth in the front, and smiled at the reflection.
#
#
# The dog leaped through the air to catch the ball.
#
#
# The top rider led the camel on a ride through the desert.
#
#
# She tracked the crowd as she performed, then ran and jumped to reach the finish line.
#
#
# The dog rolled on the grass, leaving a nice back scratch for the owner.
#
#
# She stood at the edge of the field, watched the game, and sat down to enjoy the view.
#
#
# She sat in the chair, cutting her hair with a pair of scissors.
#
#
# The pitcher threw the ball to the batter, who swung and hit it into the outfield.
#
#
# I carefully apply makeup using a soft brush to enhance my face.
#
#
# She decided to ride her bike, making sure to wear a helmet before heading out.
#
#
# She wore a shirt and jumped in the air.
#
#
# The player threw the football across the field, and the catcher caught it easily.
#
#
# She threw the ball with her arm, then dismounted from the horse.
#
#
# The runner ran down the street during the race.
#
#
# She used the rope to demonstrate how to tie a secure knot.
#
#
# She sat at the table with a glass of beer.
#
#
# The rider rode alongside the horse, chasing the bull through the open field.
#
#
# I filled the glass with beer from the tap.
#
#
# The toddler pushed the cart through the store.
#
#
# She walked down the street, watching as snow fell gently from the sky.
#
#
# He blew into the pipe, sending a plume of smoke curling into the air, where another smoke lingered from the previous breath.
#
#
# The runner sprinted down the track, leaped over the hurdle, and landed in the sand.
#
#
# She shook her head to the music as she began to dance.
#
#
# I sat on the floor and started to eat my snack.
#
#
# The fish in the pond were fed with the food provided each morning.
#
#
# The person used a paddle in the kayak, and the water covered their body.
#
#
# The farmer carefully shaved the sheep to prepare the wool for spinning, making sure to hold the comb in the right position.
#
#
# She lifted the heavy weight with a strong head of hair, dropping it slowly onto the ground.
#
#
# I used a knife to cut the pineapple's skin.
#
#
# The groom stood at the table with his dog by his side.
#
#
# I was running on the treadmill while listening to my favorite music.
#
#
# He climbed up the rope, carefully hang from it, and reached the ceiling.
#
#
# The dancer wore a bright dress and began to dance on the stage.
#
#
# The worker takes a break after a long workday.
#
#
# The alligator's tail pulled through the water, creating a ripple that echoed across the pond.
#
#
# The farmer filled the bucket with milk from the cow using his hand.
#
#
# She rode her bicycle down the hill, and when she fell, she landed on the ground.
#
#
# After a tough workout at the gym, she focused on doing a few tricep pull-downs to finish her strength training routine.
#
#
# She wore a colorful costume while dancing on the street.
#
#
# I asked him to hold the money while I signed the contract.
#
#
# I went for a walk in the forest and found a mushroom growing through the wood.
#
#
# I used the pencil, sharpened it with the sharpener, and then used the drill to make a hole in the paper.
#
#
# The chef used a knife to cut the meat and chop the vegetables on the board.
#
#
# She sat at the table, shook her head, and said nothing.
#
#
# The farmer stood near the fence, feeding the goat.
#
#
# She jumped into the pool and swam through the cool water.
#
#
# I put the cream on my leg before I shave.
#
#
# She leaned out of the window to hang the laundry, watching as the sun washed the building in golden light.
#
#
# The vendor stands in the market, selling fresh vegetable and fruit.
#
#
# She practiced her dance moves in the quiet room, preparing to perform her music piece.
#
#
# She put on her favorite shirt and held her hand over her heart while wearing it.
#
#
# I decided to take a break after riding my bike for a long time.
#
#
# On her birthday, she blew out the candles on the cake.
#
#
# She rode her bike down the ramp during the fall.
#
#
# The dog ran with a ball in its mouth.
#
#
# The owner threw the ball to the dog.
#
#
# She sat on the bench and read a paper.
#
#
# The dog ran along the path, chasing a bush.
#
#
# She jumped over the hurdle and ran through the field.
#
#
# She carefully rolled a piece of dough with her hand.
#
#
# The athlete practiced discus throw in the field, spinning with precision before launching the heavy discus.
#
#
# During the game, the team made a successful pass to the ball.
#
#
# She walked along the wall, covering it with graffiti.
#
#
# During the tennis game, he hit the ball with precision.
#
#
# We sat around the campfire, roasting marshmallows over the flames.
#
#
# A couple walked hand in hand along the street.
#
#
# The dog took a nap on the bed.
#
#
# The worker took a break by eating a sandwich.
#
#
# She rolled the dice and moved the piece across the board.
#
#
# She rode her bike down the snowy hill.
#
#
# The cook prepared a pan of sausage and roll.
#
#
# The baker mixed flour into the dough, then carefully rolled and pinned the dough to shape the bread.
#
#
# She threw the ball over the table and knocked the cup off the edge.
#
#
# The child rode the cart pulled by a donkey along the dusty path.
#
#
# She carefully **lay** the heavy **weight** on the **bench** before **lift**ing it.
#
#
# The quarterback threw the ball during the game, passing it to his teammate.
#
#
# I decided to ride my bike along the road, but I also took a walk to enjoy the scenery.
#
#
# The player threw the ball into the field.
#
#
# The machine sewed the fabric with a fine needle and strong thread.
#
#
# The dog scrubbed its fur with soap and water.
#
#
# After turning the faucet, I rinsed my hands under the water.
#
#
# She carefully shifted the gear to drive the car smoothly up the hill.
#
#
# She stood on the side of the street and watched the parade pass by.
#
#
# The rider mounted the horse and began to ride, carrying the flag through the parade.
#
#
# The player hit the ball during the club's practice on the course.
#
#
# She stood in front of the building, wearing a new jacket.
#
#
# The band played a lively march during the parade, with the instrument being the highlight of the performance.
#
#
# I looked in the mirror and ran my brush through my hair.
#
#
# The passengers stood on the platform, waiting for the train to arrive.
#
#
# She used a special tool to apply fresh plaster to the damaged wall.
#
#
# The performer stepped onto the stage and began to perform for the audience at the front of the room.
#
#
# The cowboy rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo rodeo
#
#
# She sat on the chair, carefully shaving her head.
#
#
# She folded the paper and sat at the table.
#
#
# She smiled, put her foot on the table, and couldn't help but laugh at the silly look on his face.
#
#
# The child ran across the grass, kicking a ball toward the goal.
#
#
# The team's player tried to control the ball, but the opposing team opposed the move.
#
#
# The child rode the horse while trying to hit the ball.
#
#
# I love to listen to music while I ride my bike.
#
#
# She held the racket and hit the ball hard during the tennis match.
#
#
# He hit the ball against the wall while wearing a shirt.
#
#
# I will wear my favorite shirt while grilling outside and cook a delicious meal.
#
#
# She jumped into the water and flipped the board over before it hit the bottom.
#
#
# She checked the **mirror** to adjust her **front** seat, then carefully **lifted** the **weight** of the bag from the floor.
#
#
# She went to the gym to perform a series of exercises, including using the rope for strength training.
#
#
# The jockey guided the racehorse during the thrilling ride across the track.
#
#
# The dog stuck its nose in the water, but the stick was too far from its mouth.
#
#
# She applied her makeup and looked in the mirror to check her appearance.
#
#
# I held the bird in my hand and watched it fly away.
#
#
# She sat at the table and began to eat, while they talked about their plans.
#
#
# I cracked an egg, added it to the pan, and began to cook it by frying it.
#
#
# The kid kicked the ball in the field.
#
#
# The player hit the ball and ran to first base.
#
#
# The rider rode his horse across the field, where he wore a colorful polo shirt.
#
#
# I decided to **shave** my **leg** using a **razor**.
#
#
# She sat in the chair and listened to the music.
#
#
# In the game, I used a scissor to cut the paper.
#
#
# She sat on the chair and wore a glass of water.
#
#
# He used a wrench to loosen the bolt.
#
#
# I went to the cafe to drink coffee and sit for a while.
#
#
# I used my hand to steer the car, carefully controlling the wheel as I drive down the street.
#
#
# The skateboarder took a picture of the trick.
#
#
# She sharpened the knife and demonstrated how to talk with a sharp blade.
#
#
# She sat on the chair and read a book.
#
#
# She held the paper to her face, laughing as a tear slipped down her cheek.
#
#
# She wrapped the gift and sat at the table to present it to her friend.
#
#
# She looked into the mirror, held her face in both hands, and began to paint her own reflection.
#
#
# The dog hung its tongue out as it ran along the sidewalk.
#
#
# The dog jumped into the water from the dock.
#
#
# He swung the bat and hit the ball firmly.
#
#
# The dog carried the toy through the grass.
#
#
# She used a shovel to clear the snow from the parking lot of the car.
#
#
# The spotter helped the athlete lift the heavy weight correctly.
#
#
# She practiced her jump on the mat over the bar, preparing for the landing on the land.
#
#
# The children rode their bikes around the tree, surrounded by the sound of laughter.
#
#
# I used a hammer to hit the tire and fix the flat.
#
#
# She demonstrated how to tie a necktie properly.
#
#
# The meat was placed into the grinder, and the bowl was used to collect the ground meat.
#
#
# She sat on the floor, watching the present open in front of her.
#
#
# She walked down the street, carrying a bag.
#
#
# She used the hose to hold the water while planting the flower.
#
#
# The dog jumped to catch the ball.
#
#
# The rider jumped over the obstacle while riding the horse.
#
#
# She prepared the food and made sure to wear the apron before starting the meal.
#
#
# The surfer enjoyed the thrill of riding the big wave in the vast ocean.
#
#
# The workers built a wall using bricks and mortar in the designated place.
#
#
# She used the machine to sew a piece of fabric with careful stitches.
#
#
# I pressed the button to place the card in the scanner.
#
#
# He caught the ball after practicing hard and throwing it during his baseball game.
#
#
# The athlete stood in the throw area, spun with focus, and prepared to throw the discus.
#
#
# She practiced bouncing the ball off the wall while playing tennis.
#
#
# The dog caught a snowball, but fell through the wood when it was too slippery.
#
#
# The toddler stood there, blowing tissue into his nose.
#
#
# The truck rolled slowly down the road, passing a cart that was drawing a pass through the narrow path.
#
#
# I poured the beans into the machine, roasted them, and then placed the hot beans into the bowl.
#
#
# After a strong wind, she decided to **pull** her **kite** and **ride** her **snowboard** while **holding** on to the rope.
#
#
# The dog jumped over the fence, held onto the leash, and ran toward the beach.
#
#
# She listened to the music, swayed to the rhythm, and shuffled her foot as she danced.
#
#
# I used my hand to wash the plant, then I watered it with a hose.
#
#
# The cowboy threw the lasso at the horse while watching the rodeo.
#
#
# The chef placed the spoon, plate, knife, fork, and sandwich on the table.
#
#
# She sat in the chair, washing her foot as she rowed the boat.
#
#
# The kid rode his scooter down the street, wearing a helmet.
#
#
# She knit a beautiful scarf for her friend, and they enjoyed the celebration together, learning new skills along the way.
#
#
# I used my hand to draw a piece of art on the paper with a pencil.
#
#
# She stood by the pool, splashing water with her hand, and sat down to rest.
#
#
# My father and I decided to ride our bikes together, and as we watched the sunset, I felt a deep sense of peace with my son by my side.
#
#
# The photographer took a picture of someone swimming in the water.
#
#
# After practicing jump rope, she decided to try the trampoline, but her favorite activity was still shooting basketballs into the hoop.
#
#
# The cat, with its soft fur, sat on the top of the table, enjoying the presence of its pet.
#
#
# The cowboy rode his horse to the front of the crowd, where the audience watched in awe.
#
#
# The band stretched their leg while lying on the grass, using the sunny day to relax and enjoy the moment.
#
#
# The policeman wore a jacket while riding his motorcycle.
#
#
# She lay on the grass, reading a book while her sunglasses reflected the sunlight.
#
#
# The crowd cheered loudly as the team scored a crucial goal in the final minutes of the game.
#
#
# He wore a glove to blow smoke from his cigarette.
#
#
# She stood at the front of the stage, ready to listen to the music and hold the microphone.
#
#
# I wore my headphone and listened to music as I walked through the park.
#
#
# She practiced her skate routine to perfect the skate performance and figure skills.
#
#
# She sat on the floor, back against the wall, and lay there in silence, talking to herself.
#
#
# I put the meat into the grinder and then transferred the ground meat into the bowl, which had already fallen from the counter.
#
#
# The kid sat in the seat, talking about the meal they were going to eat, with the background music playing softly.
#
#
# She held a light in her hand, juggling it with a fire ball above her head.
#
#
# I used the tool to remove the cork from the bottle.
#
#
# Let me kick the ball until I touch the ground.
#
#
# She sat on the top of the bench, wearing a short dress.
#
#
# The acrobats practiced their fall on the trapeze, knowing that the net would catch them if they swinge too hard.
#
#
# The player wore a helmet, a jersey, and blue pants.
#
#
# The chef demonstrated how to sauté a variety of vegetable using a pan.
#
#
# I placed the cookie in the oven and pulled the candy from the drawer.
#
#
# The groomsman stood next to the groom as the bride and bridesmaid walked down the aisle.
#
#
# She sat by the bed, holding a bottle of water, her head slightly shaken from the night's sleep.
#
#
# The lady held the soap and put it in her hand.
#
#
# She held the goggle in her hand and jumped into the pool.
#
#
# The player ran across the field to kick the ball toward the goal.
#
#
# The camel, guided by the desert, led the rider on a long ride through the vast sands.
#
#
# After a long day at the beach, she decided to hang her clothing out to dry and relax in the sunshine.
#
#
# She wore a hat while riding her bicycle down the street.
#
#
# The referee blew the whistle, and the spectator watched the game with great interest.
#
#
# The artist stood at the front of the arena, ready to fight for the belt before the roaring audience.
#
#
# I wear a glove to clean the toilet while brushing my teeth.
#
#
# I will give you the instruction on how to use the machine to sew a dress.
#
#
# She dragged her bike across the park, paint still smudged on her face from the ride.
#
#
# She carefully **strip**ed the **box**, **cut** the **paper** into shapes, and **wrap** it around the gift.
#
#
# I placed the pen on the table and tapped my hand to hold it steady.
#
#
# He wore a helmet and tracked the race as he mowed the lawn with the mower.
#
#
# The vehicle used for the ride was powered by the wind and sailed across the open sea.
#
#
# The caddy waited for the player to hit the ball, and the scorekeeper recorded the result.
#
#
# The dog chased a ball across the floor, and after the chase, the owner cleaned the floor with a mop.
#
#
# The father planted a tree in front of his house, where his daughter and son would later play together.
#
#
# The band member played the instrument during the march as part of the parade.
#
#
# The dog walked across the grass in the field, holding a leash.
#
#
# She adjusted her tie and stood in front of the mirror to check her appearance.
#
#
# I put my mouth to his lip and sucked the sucker from his hand.
#
#
# The kid hung a string around the doughnut and decided to eat it later.
#
#
# He used his head to block the kick, but the pad didn't hold the air well.
#
#
# She flipped into the pool, swimming in the correct direction toward the wall.
#
#
# The masseuse offered a relaxing massage on the table, carefully adjusting the patient's leg while ensuring the lie was comfortable.
#
#
# The dog ran quickly across the field to the front of the house.
#
#
# She closed her eye, rested her head on her shoulder, and took a deep breath.
#
#
# She wore a shirt and pant on the beach, but she lied about how she felt.
#
#
# The dog splashed through the puddle as the rain poured down around them.
#
#
# She rode her car down the street, passing a camel in the distance.
#
#
# She wore a blue shirt while rowing a boat near the water.
#
#
# I tried to keep the ball in the air by kicking it with my foot.
#
#
# The crowd clapped enthusiastically as everyone wore their wristbands to the concert.
#
#
# After a hard punch and a swift kick, he ran toward the bag, but he fell shortly after.
#
#
# She practiced her karate kick, carefully performing each move to block an incoming attack with her wooden training partner.
#
#
# She folded the napkin and handed it to him to demonstrate how to properly pair a tablecloth.
#
#
# She poured oil into the pan, carefully using a knife to cut the onion, then cooked the meal on a stone hearth.
#
#
# She wore a hat and a coat while sitting in a chair.
#
#
# The game began when the player hit the ball into the area.
#
#
# She pulled the cup from her hand and reached back to adjust the collar around her neck.
#
#
# He tried to open the bottle of wine, but it was stuck and he made a futile attempt to get it to stand upright.
#
#
# I wore a warm sweater while walking my dog in the snow.
#
#
# She used a bucket to wash the clothing with water, carefully rinsing each piece.
#
#
# The skier swept the snow in front of her, curling the edge of the stone as the ice crunched underfoot.
#
#
# The bird spread its wings as it soared above the water, with its body gliding smoothly through the air.
#
#
# In the midst of the war, a dog fought fiercely in the field, trying to tug the mime's sleeve.
#
#
# She sprayed paint onto the wall to add the word "art" in a bold, colorful paint.
#
#
# She waited in line to buy the cream.
#
#
# The dog was allowed to walk in the park, where it signed a petition to say that more space should be given to animals.
#
#
# The group sat on the floor, setting up a row of dominoes to see who could set the first one.
#
#
# I was walking along the pier when I checked my phone and saw my dog running toward me.
#
#
# The builder used a brick spacer to properly lay the bricks in the space.
#
#
# He used a hammer to hit a piece of metal against the anvil.
#
#
# She sat on the floor and demonstrated how to fold a shirt properly.
#
#
# The friend helped the groom and bride prepare for their wedding, and as they were about to leave, they shared a final embrace.
#
#
# He aimed carefully at the bullseye, tried to hit the target, but ended up missing, while the axe throw was completely off.
#
#
# She tied a piece of string around the package to demonstrate how to tie a secure knot.
#
#
# The crowd surrounded the flag and carried it in triumph while waving it high.
#
#
# The runner sprinted down the track, leaping over the pit and finally reaching the end of the land.
#
#
# She decided to sit on her motorcycle, wearing a helmet and a vest.
#
#
# The toddler sat at the table, holding a fork and looking at a plate of spaghetti.
#
#
# The worker took a break, sat down on the bench, and pulled out his vest.
#
#
# I sat in the field, watching the mower cut through the grass.
#
#
# The welder worked late into the night, sparking a flame that seemed to fly through the air like a streak of light.
#
#
# She used the flame to create a sculpture, knowing that a gentle blow could help her hold the fire steady.
#
#
# After the long flight, she began to walk up the stair, carefully choosing the clothing she would wear for the evening event.
#
#
# The fish in the pond can hold a bottle and feed from it.
#
#
# I will apply the hair removal product to my leg and then strip the remaining hair off.
#
#
# She sat on the chair, looked at the book, and held it in her hands.
#
#
# She sat on the floor, looking at the paperwork and staring at the wall.
#
#
# The player scored the goal in the game, helping their team to win.
#
#
# The dog ran through the field, hanging its tongue out as it walked with its mouth open.
#
#
# The runners threw the pole and watched as the track was cleared by the fast-moving team.
#
#
# She looked in the mirror, applied her mascara, and adjusted the eye.
#
#
# Pour hot water into the cup and add milk, then stir in the tea.
#
#
# The machine moved the belt to fill the bag.
#
#
# The dog fetched the disc from the yard and then ran to throw it back.
#
#
# The tool was used to fix the glass, and the pair of pliers helped to hold it in place.
#
#
# The family decorated the tree with lights and enjoyed music and dance together.
#
#
# At the end of the lift, he managed to raise the heavy bar above his head.
#
#
# She tied a rope to the tree and walked through the park.
#
#
# After finishing his chores, he jumped into the pile of leaves, leaving the rake behind.
#
#
# She used her hand to eat the last piece of cake, but she tied for a tie in the contest and couldn't bring herself to look back.
#
#
# After lunch, she sat in the truck and ate her sandwich at the front of the parking lot.
#
#
# She sat on the bench, ate a piece of cream cake while riding her bike.
#
#
# The kid walked through the snow and threw a snowball at a friend.
#
#
# She applied a type of cream to her face, rubbing it in gently.
#
#
# She sat by the fence, feeding a duck while her wheelchair was parked nearby.
#
#
# The musician wore a shirt and a guitar on the stage.
#
#
# She sat at the table, demonstrating how to play the game with the deck of cards.
#
#
# After rinsing the shirt, she tied her hair back and stepped into the sink to finish washing it before it died.
#
#
# She gave the knife to the board and threw her thumb in the air.
#
#
# He used a hammer to break the piece of rock.
#
#
# The cat lay on the floor and rubbed its belly.
#
#
# She turned her head, winked at him, and took a sip of her coffee.
#
#
# I held the string of the kite as it began to fly through the sky.
#
#
# She shook her head, danced to the music, and laughed as the rhythm filled the room.
#
#
# She took the basket, put the clothes in it, and then used the machine to wash them.
#
#
# The dog stood at the table, its fur neatly brushed.
#
#
# The kid sat on the floor, opening the present.
#
#
# The artist used a piece of canvas to create a beautiful painting.
#
#
# She tied her hair into a braid and turned her head to the side.
#
#
# Please give me the instruction on how to tie a necktie.
#
#
# After waiting for the laundry to finish, I went to the laundromat to pick up my clothes and then went to the library to read a book.
#
#
# I held the wash basin under the sink to rinse my head and hair.
#
#
# I used a knife to cut the onion into thin slices on the board, then chopped it further for the recipe.
#
#
# I will use the iron to demonstrate how to straighten the hair.
#
#
# She held a sign that promoted awareness of lesbianism and cost a dollar.
#
#
# She held the parachute as she rode the board through the water.
#
#
# The dog ran through the snow, carrying a stick in its mouth.
#
#
# The kid walked through the water, holding a balloon as part of the test.
#
#
# He lit a cigarette, adjusted his jacket, and pulled his cap down over his beard, letting the smoke curl into the cool morning air.
#
#
# The player waited for the referee to drop the puck before the game began.
#
#
# She decided to take a short picture of the street while wearing a bright blue shirt.
#
#
# The performer amazed the crowd by swallowing a sword while they watched.
#
#
# A couple walked beneath the tree as the leaves began to fall and the blossoms slowly faded.
#
#
# The surgeon wore a scrub suit before performing the surgery.
#
#
# The vendor walked through the market, selling various toys to curious visitors.
#
#
# I can drink soda and eat a hamburger.
#
#
# The couple danced on the floor while the table was set for their seat.
#
#
# The student watched as the teacher kicked the ball and held the board in place.
#
#
# The dog gently stroke its paw as it closed its face to fall into a peaceful sleep, the soft music filling the room.
#
#
# She sat on the floor, trying to put the final piece of the puzzle together.
#
#
# I poured hot tea into a glass and placed it on the table.
#
#
# The truck attached the trailer to the load with a brush.
#
#
# She sat by the window, watching as the wind blow the balloon until it suddenly popped, causing a surprise for everyone nearby.
#
#
# She stood on the sidewalk, wearing a short shirt.
#
#
# She knelt on the ground, wearing a glove, holding a lantern.
#
#
# The band marched through the field, where the crowd watched them perform.
#
#
# I push the mower across the lawn to cut the grass.
#
#
# The chef began to mix the ingredients on the counter, using a bowl to hold the mixture.
#
#
# Today, I enjoy the wind and the surf as I walk along the water.
#
#
# She lingered by the window, her arm wrapped around his waist, sharing a quiet kiss as the sunset painted the sky.
#
#
# The pedestrian had to wait while the tram crossed the street.
#
#
# The tractor was used to **remove** the snow, and a **snowblower** was **attached** to its rear for better clearing.
#
#
# I sat on the dock, watched the waves, and caught a fish with a single step.
#
#
# He decided to wear his favorite kilt and play the bagpipes while riding a unicycle for the annual festival.
#
#
# She placed the dough on the sheet and began to bake the ball in the oven.
#
#
# The machine was used to peel and remove the core of the apple.
#
#
# The skateboarder watched the crowd as he performed a daring trick.
#
#
# The gardener carefully **pruned** the **tree**, using a **shear** to **cut** the **branch**.
#
#
# The student sat in the forest, holding a pencil and reading from a book.
#
#
# I was watching a tractor hit a car in the lot.
#
#
# She rode her bike down the hill, only to flip in the water.
#
#
# She lay on the bench, lifted a weight, and watched the weights move in the gym.
#
#
# I used the slicer to break the apple into small pieces on the plate.
#
#
# The swimmer cheered loudly as the spectator watched him compete in the backstroke.
#
#
# The crowd cheered as the competitors ate their meals before the contest began.
#
#
# She pumped air into the balloon, danced in the room, and raised her fist in triumph.
#
#
# He sat on the bed, prepared to shave his leg with a razor.
#
#
# I walked into the store and touched the shirt in the section.
#
#
# I carefully **scoop**ed the **watermelon** and **cut** **open** the **inside** to enjoy the juicy flesh.
#
#
# The dancer performed a graceful routine on the stage in front of a lively audience.
#
#
# She carefully **apply**ed her **makeup** to create the perfect **look**, making sure her **eyebrow** was perfectly shaped to complete the **demonstrate**.
#
#
# I sat at the table and folded the paper into a shape.
#
#
# I held the mug and sunglass on top of my head.
#
#
# The chef works in the kitchen to prepare delicious food by cooking.
#
#
# She used her hand to lift the weight during the arm exercise.
#
#
# She sat at the front of the table, laughing as she shared her favorite food with the group.
#
#
# After a long ride, the man knocked on the mailbox, hoping to catch a beat from the bat that was stuck in the truck.
#
#
# She carefully moved her finger along the guitar's fret to hold the note in place.
#
#
# After finishing her coffee, she went to the park to read the newspaper.
#
#
# She sat on the floor, carefully clothe the suitcase, and began to pack her belongings.
#
#
# After a long walk through the city, she noticed a new mark of graffiti on the wall near the old store, and decided to close the door behind her.
#
#
# The worker on the crew directed the traffic to ensure smooth flow during the work shift.
#
#
# I picked a piece of pumpkin and threw it into the air.
#
#
# The dog ran quickly through the water, and the bear lost a tooth in the process.
#
#
# The mother helped the toddler clothe the baby while they waited for the washer to finish.
#
#
# She sat on the bench, holding an umbrella and a jacket.
#
#
# She combined sliced onion, cucumber, and pasta in a bowl.
#
#
# Please wrap the injured leg with a bandage and follow the instruction to give proper care.
#
#
# I poured oil into the tray and placed the sausage in the oven to bake.
#
#
# The cook placed the skewer of meat on the barbecue and turned it to ensure it was cooked evenly.
#
#
# She walked along the sidewalk, talking on her phone while wearing a blue shirt.
#
#
# I will explain how to cook a sausage on the grill by placing it on the hottest part of the grill.
#
#
# She wore appropriate clothing to perform the activity in the building.
#
#
# The waiter asked me to look at the menu and take the order.
#
#
# I opened my mouth to treat the dog, but I caught him sneaking a piece of bread.
#
#
# The bat hit the ball, and the machine came to life.
#
#
# She wore a blue shirt and jeans, standing in the field with the sun setting behind her as the background of the day.
#
#
# The player shook hands with the team member, but the team opposed the decision to shake hands.
#
#
# She walked down the street, talking on her cellphone while checking her dress.
#
#
# The bus arrived, and people began to sit on the bench, waiting for the next stop.
#
#
# She stood at the door, her expression calm as she faced the ladder leaning against the wall.
#
#
# The lady swept the sidewalk, her dress worn but still elegant.
#
#
# He looked in the mirror, carefully trimming his beard with the scissor.
#
#
# She decided to wear a lollipop in her pocket, made sure to hold the boot steady, and walked along the fence.
#
#
# The dancer began her routine by twirling with a bright red baton in hand.
#
#
# The couple took a walk in the park with their dog.
#
#
# The toddler sat on the floor, picking up a bead and tying it to a string.
#
#
# A flock of birds flew past the mural on the side of the building.
#
#
# After the flood, we had to walk along the road through the water to get to the drive.
#
#
# He took a piece of wood and used the axe to chop it into smaller pieces.
#
#
# I turned the toast over, placed it on the grill, and used my hand to press down on the bun.
#
#
# She sprinkled flour over the dough, then carefully cut a half of the bread.
#
#
# The runner jumped over the hurdle during the race on the track.
#
#
# The toddler held the broom and swept the floor.
#
#
# She folded the paper to demonstrate how the music could be played against the background of the performance.
#
#
# The church held a special event where the congregation gathered to dance, clap to the music, and celebrate together.
#
#
# She used a tool to paint a piece of art on the street to create a beautiful mural.
#
#
# The husband asked his wife to stand next to him so they could take a picture together.
#
#
# The tourist took a photo with an umbrella and a bicycle.
#
#
# The crowd cheered as the swimmer competed in the final race.
#
#
# She sat at the table, opened the bottle, and poured the wine into a glass.
#
#
# The crowd cheered loudly as the winner of the contest took the stage to eat the first bite of the grand prize.
#
#
# She used a stone to sharpen the knife, explaining the importance of keeping it sharp for safe cooking.
#
#
# She wore a red dress, held a bag in her hand, and stood by the door.
#
#
# She filled the bowl with food and smiled as it held the warmth of her favorite meal.
#
#
# She wore a colorful hat and face paint for the carnival costume party.
#
#
# The cowboy threw the back of the horse into the air.
#
#
# I read through the book, turning each page carefully.
#
#
# She crossed the river by driving through the water.
#
#
# She carefully **separate** the **bottle** and **demonstrate** how to **egg** the mixture.
#
#
# I went to the restaurant and ordered to eat, drink, and enjoy a glass of wine.
#
#
# The dog ran after the rabbit, trying to catch it.
#
#
# The bus stopped at the bus stop, and people had to wait in line for the next bus.
#
#
# My mother said, "Bless you" as she sneezed.
#
#
# She used a clip to hold back her hair while the therapist gave her a relaxing foot massage and trimmed her nail.
#
#
# She wore a short dress and walked confidently down the street.
#
#
# She sat on the ground and pushed the wheelbarrow as the fall of leaves surrounded them.
#
#
# The knight pulled the sword from the stone, but the dragon's fiery breath forced him to swallow the hot smoke that entered his mouth.
#
#
# I decided to direct my walk along the busy street to avoid the heavy traffic.
#
#
# She applied a gentle massage to her face to help improve the product's effectiveness.
#
#
# I held the cup in my hand while watching a bird eat from it.
#
#
# She shuffled the cards and sat on the floor to play.
#
#
# I used my tongue to lick the sticky substance off my lip.
#
#
# The couple decided to take a walk in the park.
#
#
# I decided to look up a recipe for grilled meat and then go cook it on the grill.
#
#
# I held the weight in my hand at the gym.
#
#
# She used the brush to style her hair before running it through the dryer.
#
#
# The couple danced in their favorite outfit on the stage.
#
#
# She began to **perform** her song, with the **music** playing in the **background**, as she **moved** gracefully across the stage.
#
#
# He sat by the pipe, listened to the music, and watched the smoke rise from the fire.
#
#
# The kid built a snowman in the snow.
#
#
# He stood in front of the board, ready to throw the knife.
#
#
# The cow stood by the stool, waiting for the farmer to sit and pour milk from the bucket.
#
#
# She held the microphone as she sang the song, her voice clear and powerful.
#
#
# I used a pencil to draw a picture on the paper.
#
#
# She wore her new cap on the roof while working on the garden.
#
#
# The bulldozer pushed the dirt to form a big pile.
#
#
# I sat on the bed and practiced the guitar song.
#
#
# Wait for the traffic to clear before crossing the road.
#
#
# The dog jumped into the pool with a toy in its mouth.
#
#
# The kid shot the ball into the hoop.
#
#
# I used my **hand** to **hold** the **bag**, which helped me **carry** my groceries home.
#
#
# She rode her horse along the winding mountain trail.
#
#
# She jumped in the air and took a picture of the sunset.
#
#
# She threw the ball onto the floor and then sat down.
#
#
# The child stuck his hand in the field, ran toward the fence, and held on to the stick as he tried to escape.
#
#
# The dog squirted water from the jet.
#
#
# She walked along the sidewalk near the front of the building.
#
#
# She tied the shirt around her waist and wore the tie proudly.
#
#
# I will eat lunch and watch a movie after work.
#
#
# She carefully **hold**ed her **finger** on the **guitar** strings as she **move**d her hand across the fretboard.
#
#
# I peeled the potato and sat at the table.
#
#
# Wait, treat your dog to a walk, and then sit down to rest.
#
#
# I went to the gas station to pump gas into my car.
#
#
# I saw a piece of wood with a saw.
#
#
# She held his hand as the music began and the dance started.
#
#
# The worker carefully polished the metal piece on the machine.
#
#
# The dog jumped and held the stick in its mouth.
#
#
# I love to watch cartoon shows and wear my new headphone while relaxing.
#
#
# She wore a hat while working on her project.
#
#
# I used a cap to open the bottle.
#
#
# She was playing card games in the house, building a deck to use for the next game.
#
#
# She held his hand as they talked about the snake that had been seen in the forest.
#
#
# She sharpened the knife before cutting the carrot.
#
#
# After a tough workout at the gym, she landed a powerful punch and a sharp kick, all while carrying her gym bag in hand.
#
#
# He watched the ball hit the ground and continued to run.
#
#
# She continued to capture the smooth movement of the horse as they rode together down the winding trail.
#
#
# She wore a blue shirt and carried a bag with her.
#
#
# I decided to lie on the table and receive a relaxing massage.
#
#
# She rode her bike down the hill, jumped over the hurdle, and hit the ground with a thud.
#
#
# The family gathered around the table for dinner and began to eat.
#
#
# She carefully **apply**d her **mascara** to her **eye**, making sure to **look** sharp for the interview.
#
#
# The athlete demonstrated a new technique by delivering a powerful kick to the ball.
#
#
# She sat in the chair and held the instrument.
#
#
# She sat at the table, admiring the art and craft on display.
#
#
# He worked hard in the baseball field during his daily practice, trying to hit the ball accurately.
#
#
# I touched my eye and nose as I crossed the street.
#
#
# She wore a waterproof jacket to stand against the rain.
#
#
# The worker stood on the side of the building, preparing to start his work.
#
#
# She pulled the snowboard toward her, held the kite steady in the wind.
#
#
# I watched the plane flying over the beach as the sky turned dark.
#
#
# The sun set behind the ocean, and I stood there watching the beautiful view.
#
#
# She walked down the street in a colorful costume dress.
#
#
# She cracked an egg into a bowl and beat it with a fork.
#
#
# She began her dance on the stage, with the middle of the performance marking the peak of her energy.
#
#
# We enjoyed a wonderful day at the beach with our family.
#
#
# Add ice to the glass of liquor.
#
#
# She went to the gym to squat with the weight on her shoulder.
#
#
# The machine was used to fill the bag with contents, and then the seal was applied to close it.
#
#
# I used tape to pull and remove the hair from the stubborn knot.
#
#
# The pen hit the desk as the music played softly in the background.
#
#
# The dog chased the cat down the street.
#
#
# I cracked an egg into a bowl in the kitchen.
#
#
# She sat by the sink and held the toothbrush in her hand.
#
#
# I went to the store to finish my shopping, but I had to wait for my wife to arrive.
#
#
# She wore a colorful hat while dancing to the upbeat music.
#
#
# The dog tried to catch the toy with its mouth.
#
#
# The horse stood with its tail swishing as I brushed its fur gently with the brush.
#
#
# I put the cap on the machine and then filled the bottle.
#
#
# The officer gave the report to the team, pointing to the map on the front of the table.
#
#
# The lady decided to talk to her friend while wearing a stylish jacket.
#
#
# The swimmer cheered loudly as she prepared for the race in the pool.
#
#
# The blacksmith struck a metal piece with a hammer, sending a loud hit through the workshop.
#
#
# The dog ran through the grass, chasing a toy with its mouth.
#
#
# She carefully inserted the lens into the device, hoping it would improve her view through the eye.
#
#
# The path was surrounded by trees, and I decided to take a walk along it.
#
#
# After a hard workout, she decided to **jump** over the **bar**, **swinge** her arms, and **continue** with her routine.
#
#
# I went to the gym to work out my arm using the equipment provided.
#
#
# The dog stood on the grass, and the owner watched from a distance.
#
#
# She ran down the path, leaped over the pit, and jumped to avoid the falling rocks.
#
#
# He sat on the chair, smoking from the pipe.
#
#
# I took a picture of the mountain with my friend.
#
#
# The kid ran over to the balloon and threw it into the air.
#
#
# She sat on the rock, overlooking the calm water below.
#
#
# I walked through the grass with my dog, holding a stick in my hand.
#
#
# She practiced her skateboard trick in the park, making sure to perform it perfectly.
#
#
# Please give me the instruction to braid my hair.
#
#
# She shook her head, smiled, and looked at the sunset.
#
#
# He used a mallet to hit the gong, standing firmly in place.
#
#
# She held the flute to her mouth and blew a soft, melodic tune.
#
#
# She sat on the floor and began to pack her suitcase.
#
#
# He spent hours practicing basketball, focusing on improving his dribble and timing during each play.
#
#
# She wore a helmet to stay safe as she explored the dark, narrow passages of the cave, where the light from her headlamp barely reached.
#
#
# The lady put the sheet on the bed.
#
#
# She sat on the couch and brushed her hair.
#
#
# She adjusted her **hat**, **folded** the **arm** of her jacket, and stood **stand** in front of the mirror.
#
#
# She raised her arm to point to the top of the mountain.
#
#
# Please follow the instruction and use the sewing machine to sew the fabric together, and I will give you further guidance.
#
#
# She decided to hold the animal and make sure to stand steady while she held the stuff in her hands.
#
#
# He lifted the heavy bar with all his strength, knowing that the weight of the task would determine whether he could successfully end his training session.
#
#
# The dog jumped over the wave as they ran toward the beach.
#
#
# The snowboarder performed a trick in the air during the competition.
#
#
# The dog ran across the ground, covering the area with its footsteps.
#
#
# The car stopped on the street, and the pedestrian filled the silence with a polite hello.
#
#
# ...
#
#
# She carefully **clothe**d the model, **hold**ing the fabric in place as she **dress**ed her in the latest collection, **pose**d for the photographer, and **drank** a cup of coffee before the session.
#
#
# She walked along the tightrope, holding the front of her dress tightly against the crowd.
#
#
# The team sang a song and held the trophy together.
#
#
# I wish I could sit by the table and blow out the candle.
#
#
# She rode her bike along the sidewalk, ringing the bell as she passed the store.
#
#
# The player practiced passing the ball on the field during the training session.
#
#
# The surfer performed a daring trick on the surfboard as they glided across the water, their body perfectly balanced in the rhythm of the waves.
#
#
# He wore his helmet, stood by the stand, and sang a song while his gun was on the stand next to his sunglass.
#
#
# The teacher composed a lesson plan to teach the class how to hold a scarf properly.
#
#
# The horse followed the ball as it ran through the snow.
#
#
# She looked down at the sidewalk, sat on a bench, and took a photograph from a low angle.
#
#
# She sat at the table, holding a notebook and a pen, while her laptop lay open on the surface.
#
#
# The couple danced in the room while the others watched the music play.
#
#
# The dog stood at the edge of the river, turned its head, and looked toward the distant horizon.
#
#
# She held the bull's hand in the air as they rode together through the arena.
#
#
# She rode down the snowy hill on a red sleigh.
#
#
# The wrestler began the match by shaking hands with his opponent before the fight began.
#
#
# The dragster left a long trail of smoke as it took off down the track.
#
#
# She wore a drum kit in the corner of the room while listening to music through her headphone.
#
#
# She sat on the sidewalk, drawing a picture with chalk.
#
#
# The couple held a bouquet of flowers and shared a gentle kiss.
#
#
# The skateboarder gracefully **flip**ed over the **rail**, **pass**ing by the **turn** and **skate**ing smoothly down the slope.
#
#
# The car stood on the roof of the house, its engine still running, showing off its powerful wash.
#
#
# She sharpened the knife with a spinning wheel.
#
#
# The word "street" was painted in bold letters at the front of the building, and everyone looked at it in surprise.
#
#
# I attached the curling iron to the dryer device and brushed my hair to style it.
#
#
# She wrapped a bandage around her foot and put on a glove to wear during the game.
#
#
# She wore blue jeans down the lane, watching the ball roll toward the goal.
#
#
# She sat on the porch, held a cigarette between her fingers, and stepped outside to smoke while wearing a casual shirt.
#
#
# She put the shovel in the bucket and dug a hole in the sand.
#
#
# At the end of the meal, she used her fork to lick the last bit of food off the plate.
#
#
# The farmer worked in the field, cutting through the grass with a scythe.
#
#
# The child stood on the sand, holding a tire with their mouth.
#
#
# She attached the sail to the tricycle and rode it along the beach.
#
#
# She sat on a mound of rocks, wearing a blue shirt and a white top.
#
#
# He took a deep puff from his pipe, filling his lungs with smoke and fresh air.
#
#
# A squirrel ran through the forest, trying to catch a dog that was chasing it.
#
#
# Daddy threw the rock into the stream, watching as it skipped across the water, smiling at his playful daughter.
#
#
# She took a deep breath, stepped back, and then threw the javelin as the fall of autumn surrounded them.
#
#
# The hiker poked the snow with a stick and finally found a hidden tent in the icy wilderness.
#
#
# He inspected the truck's bed to make sure it was in good condition and would spur him on during the long journey.
#
#
# I gave my dog a dry bath and then used a towel to dry him off.
#
#
# She looked out the window, wondering how to connect the parachute to the doll, but then she decided to throw it away.
#
#
# The worker rode the tractor through the field, picking vegetables for the market.
#
#
# The heavy **load** on the **roof** of the **building** was caused by the **car** that was parked there, making it a significant **object** of concern.
#
#
# The dog jumped over the hurdle before the fire at the end of the race.
#
#
# I carried my daughter in the stroller and pushed her with my hand.
#
#
# She decided to get a tattoo on her arm, standing in front of the guitar store to decide which one to choose.
#
#
# I will take a picture of the plant while wearing a helmet.
#
#
# Sit on the couch and describe the smooth, rich taste of the wine.
#
#
# She applied paint to the car, wearing a mask and a suit, while spraying the surface with a can of paint.
#
#
# He tied a rope around his waist and began to climb the mountain, carefully checking that the rope was securely covered with a protective cloth.
#
#
# After hearing the voice on the radio, she decided to follow the shot and continue the series.
#
#
# The kid hit a baseball during the game, and the basis of the play was a successful run.
#
#
# I used a pen to draw a picture on the paper.
#
#
# I leaned over the sink, pouring water from the tap as I wiped my head with a towel.
#
#
# She used a rope to climb up the gym wall, suspending herself from the ceiling.
#
#
# The onlooker stood on the path, watching as the stilt-walker gracefully walked along the edge of the water.
#
#
# The referee watched the action in the ring as the crowd cheered for the boxers.
#
#
# The team watched the game as the crowd cheered loudly, all eager to see them compete.
#
#
# She stood at the top of the hill, gazing up at the sky as the moon illuminated the night.
#
#
# She spread her arms wide, jumped into the air, and stretched her leg as she landed.
#
#
# The alligator sat in the back of the room, ready to tell a joke.
#
#
# She used a knife to open the oyster and looked at its shiny interior.
#
#
# The athlete stood on the ice, careful to keep his foot steady as the mat broke under his weight.
#
#
# They celebrated their victory by opening a bottle of champagne.
#
#
# Sheep are sheared using a clipper to remove the wool.
#
#
# She sat on the chair, clapped her hands, and gave a sharp snap with her finger.
#
#
# The machine was used to bend and pull the string, creating a repetitive pattern that required careful repetition.
#
#
# The kid held a hand in a circle while dancing.
#
#
# I decided to sign up for the event, so I asked the organizer to help me eat and walk around the venue.
#
#
# She gently wrapped a cloth around her **neck**, then placed a soft **kiss** on her **forehead**, as her **arm** rested lightly on his shoulder.
#
#
# I removed the cookie from the pan and put it in the oven.
#
#
# She carried the ball into the water, and it splashed into her mouth.
#
#
# While digging through the sand, we found a gem and began to sort the gold among the treasures.
#
#
# They gathered snow to create a snowball on the bench.
#
#
# The bottle sat on the table, with a line drawn on the front of the paper.
#
#
# I held the dog by the front as it tried to bite the puncture ball.
#
#
# The cat sat on the lap, scratching its head.
#
#
# He used the cue to shoot the ball into the pocket.
#
#
# After brushing her hair, she stepped over her foot and lay down on the blanket.
#
#
# He jumped in the air to catch the ball with his mouth.
#
#
# I found a **piece** of **paper** in my **pocket**, which was inside a **book**, and a **slip** of paper fell out.
#
#
# The toddler clapped her hand as she sang a song, her skin singe from the flame.
#
#
# The machine wrapped the plastic around the front of the stand.
#
#
# She carried her bag, jeans, and sweater in a cozy pattern.
#
#
# She held the bag in her hands, stood tall, wore a smile, and the day ended with a sense of accomplishment.
#
#
# He used a rope to hang from a rock, preparing to climb the steep cliff with his belt securely fastened.
#
#
# The toddler fell out of the bed and left a strong smell on the foot of the sleeping parent.
#
#
# The soldier stood in the background, watching as the member of the team enacted a dramatic scene from the mission.
#
#
# The dog stood by the stream, wading through the water with its foot submerged.
#
#
# The dog bit the bucket while climbing the pine tree.
#
#
# She used a pen to write beautiful calligraphy on the paper.
#
#
# She flipped through the book, sitting on the bed and turning the page.
#
#
# I used a penny to check the tread on my tire.
#
#
# He held the pipe, blow smoke into it, and shaped the smoke into a small cloud.
#
#
# The rider jumped into the snow, while the crowd watched in amazement.
#
#
# She unrolled the paper and placed it on top of the box.
#
#
# The dog jumped over the bottle while trying to reach the goat for feed.
#
#
# The player swung the bat and hit a home run during the baseball game.
#
#
# Put water into the pot and fill the stove.
#
#
# The worker checked the area and confirmed that the vest was made of the correct material.
#
#
# He held a glass to his mouth, wearing a pipe in his hand.
#
#
# He sat in the chair, ready to shave the area above his head.
#
#
# The weather forecaster stood in front of the screen, pointing to the forecast and talking about the coming storm.
#
#
# Today, I watched my dad fix the fence, and he told me to kick the ball.
#
#
# The toddler used a toothbrush to brush her teeth.
#
#
# She carefully poured the liquid from the jar onto a cloth, making sure to keep the cover on to prevent any spillage.
#
#
# The animal opened its mouth to feed and receive the food.
#
#
# The little kid pulled off his sock, snuggled under the blanket, and finally fell asleep after a long day, with a jeans jacket still on.
#
#
# At the gas station, she said she would hack the system to get free gas, but the pump was already broken.
#
#
# She sat on the grass, her body leaning slightly as she rode her bicycle along the edge of the water.
#
#
# He threw the knife into the wood, leaning against the tree.
#
#
# The player stood in the field, swung at the ball, and hit it deep into the outfield.
#
#
# She decided to **harness** her creativity by **painting** the **side** of the **building** and **hang** her artwork on the **side** as well.
#
#
# She used a pick to climb the ice wall.
#
#
# The vacuum began to turn on the floor.
#
#
# The bottle hit the wall with a loud bang, sending a cork flying through the air.
#
#
# The farmer moved down the street, planting a seed in the soil, hoping it would grow into a tree that would bear fruit.
#
#
# I began to look in the mirror to shave my face.
#
#
# She wore a sleek machine on her back, sculpting a new monument to her legacy.
#
#
# The groomer carefully trimmed the dog's fur to ensure it would hold its shape after the grooming session.
#
#
# She ran to the tree, grabbed a branch, and pulled it down.
#
#
# As she walked through the doorway, a long shadow was cast by the light.
#
#
# She went to the gym to perform a lunge and make sure she held the correct weight during her workout.
#
#
# There was a banana stand on the street where a child looked into the bowl with curiosity and touched the head of a banana.
#
#
# I fried an egg in the pan, then transferred it to a plate.
#
#
# After dropping the baton, she decided to continue her routine, but forgot to pick it up again.
#
#
# She enjoyed a leisurely ride along the road through the quiet area, where the woode was still fresh from the morning's work.
#
#
# The drummer used his hand to beat the drum, with his finger pressing down on the top.
#
#
# The man pulled the cart down the street, filling the chair with groceries.
#
#
# She wiped the sweat from her **face**, but the **belly** of the **shirt** still **exposed** the **belly** of the **shirt**.
#
#
# The child blew dust from the teapot into the air, and the teacher asked if the student was wearing a hat to cover his nose and protect it from the cold wind.
#
#
# She opened the bottle of water, put it to her mouth to drink, and then wore her sunglasses to protect her eyes from the sun.
#
#
# She poured water into the pool to help clean the side with a sponge.
#
#
# She held the photo in her hand, looked at the gallery, and checked the bag for any missing items.
#
#
# She sat on the mountain, wearing a backpack on her side.
#
#
# She carefully **weave**ed the **basket** together, **apply**ed **glue** to the seams, and **cut**ted the excess strands to finish the project.
#
#
# She took a shot of whiskey, licked the salt off her hand, and smiled.
#
#
# The cheerleader practiced her routine, prepared to perform, and the audience watched as she took the court.
#
#
# She paused, examined the building from the front of the table.
#
#
# The toddler tried to hold the phone to her ear but couldn't talk because it was too heavy.
#
#
# I looked in the mirror to fix my hair and make sure I wore the shirt properly.
#
#
# I sprayed water on my face, put my hand over the fountain, and stepped back to see the short spray mist around me.
#
#
# I decided to put the fire out by sticking a stick in the background while we talked.
#
#
# After sitting for a long time, she stretched her leg and gave her foot a gentle massage to relieve the cross.
#
#
# The lady walked through the mall, wearing a colorful costume.
#
#
# She sat on the floor, holding a pencil, with a point in her hand.
#
#
# The player wore a red shirt and a ball, hoping to improve their score in the game.
#
#
# The nurse carefully lied about the patient's condition, shaved his knee, and placed him back on the bed.
#
#
# The pitcher threw the ball while wearing his uniform.
#
#
# The puppy tugged at the fabric strip during the war.
#
#
# The skier raced down the hill, jumped off the edge, and hit the land with a loud thud.
#
#
# The couple walked along the wall, admiring the graffiti on the side of the car.
#
#
# The kid sat under the tree and hung the flag.
#
#
# She sprinkled sugar powder over the top of the cake.
#
#
# The writer, who had been a frequent goer of the bookstore, looked at the heart-shaped locket and decided to leave it behind.
#
#
# The hiker began to climb the mountain, and as the sun came up, he finally reached the top, holding onto the rope for support.
#
#
# She carefully picked up the marble and placed it in the cup with her foot.
#
#
# He carried a sack of paint to the front of the wall to add more graffiti.
#
#
# The player had to **hold** the **football** **upright** as he prepared for a powerful **kick** on the **field**.
#
#
# The male sold money on the street for food.
#
#
# The dog chewed on the gum, scratching its nose as it whispered a secret to itself.
#
#
# The cow stood by the stool, waiting to sit and drink from the pail of milk, but the farmer's utter frustration was evident.
#
#
# The robot smiled as it wore its sunglass and gave a hug to the surprised visitor.
#
#
# He walked down the street, selling flowers and lighting a cigarette.
#
#
# She sat by the screen, looking at the headphones she was wearing.
#
#
# She wore a mask to protect herself, and the individual stood behind the fence, trying to match the rhythm of the music.
#
#
# She enjoyed the peaceful **background** **music** as she took a leisurely **ride** on her **bike** through the quiet **snow**-covered trail.
#
#
# The player tried to reach the shuttlecock with a strong backhand during the intense competition.
#
#
# She sat on the rock pile, wearing a hat and holding a knit scarf.
#
#
# The lady looked at the dentist and decided to wear a mask before the appointment.
#
#
# The man adjusted the light on his shirt top and carefully fixed the roof of the car.
#
#
# The worker used a tool to improvise a way to transport the barrel from one place to another.
#
#
# After finishing her lunch, she stepped outside, sat on the bench, picked up her bag, and poured a cup of coffee to eat.
#
#
# The cat began to squirm as the claws cut into its skin.
#
#
# After washing the dishes in the sink, she began to dance to the rhythm of the song.
#
#
# She fell off her bike, lost her balance, and had to ride her board back to the starting line.
#
#
# I opened the tissue pack to wipe my nose.
#
#
# The worker stood on the street, trying to place a brick on the stand, but failed in his attempt.
#
#
# The golfer wore a stylish jacket and a pair of pants, holding a club in his hand.
#
#
# I will take a picture of the mirror, making sure to hold the gear steady.
#
#
# She tied a rope to the wall and used it to hold the exercise equipment steady while a wave of people passed by.
#
#
# I squeezed the handle, shut my eye, and let my head hang loosely as I waited for the signal.

# %%
df['free_gen_result'] = [s.split('</think>')[1] for s in results]

is_ok = []

def is_include_all_words(str, concepts: list) -> bool:
    return all(word in str for word in concepts)

for _, row in df.iterrows():
    ok = is_include_all_words(row['free_gen_result'], row['concepts'])
    is_ok.append(ok)

df['is_free_gen_ok'] = is_ok

df
# Out:
#       concept_set_idx                                 concepts target  \
# 0                   0                [team, run, drill, field]
# 1                   1               [goal, player, take, shot]
# 2                   2             [dog, frisbee, throw, catch]
# 3                   3                [food, front, table, sit]
# 4                   4         [front, sit, guitar, microphone]
# ...               ...                                      ...    ...
# 1492             1492  [worker, street, brick, stand, attempt]
# 1493             1493       [pant, wear, golfer, club, jacket]
# 1494             1494      [mirror, gear, hold, picture, take]
# 1495             1495        [tie, exercise, rope, wall, wave]
# 1496             1496         [squeeze, shut, head, eye, hang]
#
#                                         free_gen_result  is_free_gen_ok
# 0      \n\nThe team practiced a new drill on the field.           False
# 1               \n\nThe player took a shot at the goal.           False
# 2     \n\nI threw the frisbee to my dog, and he caug...           False
# 3     \n\nShe sat at the front of the table to eat t...           False
# 4     \n\nShe sat at the front of the stage, holding...           False
# ...                                                 ...             ...
# 1492  \n\nThe worker stood on the street, trying to ...            True
# 1493  \n\nThe golfer wore a stylish jacket and a pai...           False
# 1494  \n\nI will take a picture of the mirror, makin...            True
# 1495  \n\nShe tied a rope to the wall and used it to...            True
# 1496  \n\nI squeezed the handle, shut my eye, and le...            True
#
# [1497 rows x 5 columns]

# %%
df['is_free_gen_ok'].mean()
# Out:
# np.float64(0.541750167000668)

# %%
import random
import heapq, itertools, torch






enc = tok(prompts, return_tensors="pt", padding=True).to(model.device).input_ids

results = []
for input_ids, c in tqdm(zip(enc, df['concepts'].tolist()), total=len(df)): 
    for i, (seq, neg_logp) in enumerate(variants(input_ids)):
        text = tok.decode(seq, skip_special_tokens=True)
        if '</think>' in text:
            text = text.split('</think>')[1].strip()
        else:
            continue
        if is_include_all_words(text, c):
            results.append(text)
            break
        if i > 40:
            results.append("")
            break
# Out:
# 100%|██████████| 1497/1497 [56:56<00:00,  2.28s/it]

# %%
df['contrained_gen_result'] = results

is_ok = []

for _, row in df.iterrows():
    ok = is_include_all_words(row['contrained_gen_result'], row['concepts'])
    is_ok.append(ok)

df['is_contrained_gen_ok'] = is_ok

# %%
df['is_contrained_gen_ok'].mean()
# Out:
# np.float64(0.9799599198396793)
